# %% [markdown]
# ## UNETR model Configration

# %%
""" UNETR Configration """

from keras.optimizers import Adam

cf = {}
cf["image_size"] = 256
cf["num_layers"] = 12
cf["hidden_dim"] = 128
cf["mlp_dim"] = 32
cf["num_heads"] = 6
cf["dropout_rate"] = 0.1
cf["batch_size"] = 16
cf["lr"] = 1e-4
cf["optimizer"] = Adam(cf["lr"])
cf["patch_size"] = 16
cf["num_patches"] = (cf["image_size"] ** 2) // (cf["patch_size"] ** 2)
cf["num_channels"] = 3
cf["flat_patches_shape"] = (
    cf["num_patches"],
    cf["patch_size"] * cf["patch_size"] * cf["num_channels"]
)
# Out:
# 2024-03-26 04:54:38.422043: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 04:54:38.422132: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 04:54:38.579703: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## Create functions for loading dataset

# %%
from glob import glob
import os
from sklearn.model_selection import train_test_split
import cv2
import numpy as np
import tensorflow as tf
from patchify import patchify
from keras.preprocessing.image import ImageDataGenerator


def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)


def load_dataset(path, split=0.2):
    # Get paths of images and masks
    images_paths = sorted(glob(os.path.join(path, "images", "*.png")))
    masks_paths = sorted(glob(os.path.join(path, "masks", "*.png")))

    split_size = int(len(images_paths) * split)

    train_x, valid_x = train_test_split(
        images_paths, test_size=split_size, random_state=42)
    train_y, valid_y = train_test_split(
        masks_paths, test_size=split_size, random_state=42)

    train_x, test_x = train_test_split(
        train_x, test_size=split_size, random_state=42)
    train_y, test_y = train_test_split(
        train_y, test_size=split_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)
    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)


def augment_data(images_paths, masks_paths, num_aug_per_image=2, aug_save_path="/kaggle/working/Augmented_Dataset"):
    """
    Perform data augmentation on images and masks.

    Args:
        images_paths (list): List of file paths to original images.
        masks_paths (list): List of file paths to corresponding masks.
        num_aug_per_image (int, optional): Number of augmented versions to create per image. Defaults to 3.
        aug_save_path (str, optional): Directory to save augmented images and masks. Defaults to "Augmented_Dataset".

    Returns:
        tuple: A tuple containing lists of augmented image paths and mask paths.
    """
    # Create directories to save augmented images and masks
    images_aug_dir = os.path.join(aug_save_path, "images")
    masks_aug_dir = os.path.join(aug_save_path, "masks")

    create_dir(images_aug_dir)
    create_dir(masks_aug_dir)

    for (img_path, mask_path) in zip(images_paths, masks_paths):
        # Read the image and mask
        image = cv2.imread(img_path, cv2.IMREAD_COLOR)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

        # Initialize an ImageDataGenerator for augmentation
        aug = ImageDataGenerator(
            rotation_range=10,
            zoom_range=0.2,
            brightness_range=[0.7, 1.3],
            horizontal_flip=True,
            fill_mode="nearest"
        )

        # Extract the base filename (without extension) for saving augmented images
        id = os.path.splitext(os.path.basename(img_path))[0]

        # Augment the image
        num_aug = 0
        for _ in aug.flow(np.expand_dims(image, axis=0), batch_size=1, save_to_dir=images_aug_dir, save_prefix=f"{id}_aug", save_format="png", seed=42):
            num_aug += 1
            if num_aug >= num_aug_per_image:
                break

        # Augment the mask
        num_aug = 0
        for _ in aug.flow(np.expand_dims(mask, axis=(0, -1)), batch_size=1, save_to_dir=masks_aug_dir, save_prefix=f"{id}_aug", save_format="png", seed=42):
            num_aug += 1
            if num_aug >= num_aug_per_image:
                break

    # Get paths of augmented images and masks
    aug_images_paths = sorted(
        glob(os.path.join(aug_save_path, "images", "*.png")))
    aug_masks_paths = sorted(
        glob(os.path.join(aug_save_path, "masks", "*.png")))

    # Combine original and augmented paths
    images_paths.extend(aug_images_paths)
    masks_paths.extend(aug_masks_paths)

    return images_paths, masks_paths


def read_image(path):
    path = path.decode()
    image = cv2.imread(path, cv2.IMREAD_COLOR)
    image = cv2.resize(image, (cf["image_size"], cf["image_size"]))
    image = image / 255.0

    """ Processing to patches """
    patch_shape = (cf["patch_size"], cf["patch_size"], cf["num_channels"])
    patches = patchify(image, patch_shape, cf["patch_size"])
    patches = np.reshape(patches, cf["flat_patches_shape"])
    patches = patches.astype(np.float32)

    return patches


def read_mask(path):
    path = path.decode()
    mask = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  # (256, 256)
    mask = cv2.resize(mask, (cf["image_size"], cf["image_size"]))  # (256, 256)
    mask = mask / 255.0  # (256, 256)
    mask = mask.astype(np.float32)  # (256, 256)
    mask = np.expand_dims(mask, axis=-1)  # (256, 256, 1)
    return mask


def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape(cf["flat_patches_shape"])
    y.set_shape([cf["image_size"], cf["image_size"], 1])
    return x, y


def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %% [markdown]
# ## Build the UNETR model

# %% [markdown]
# UNETR - Unet Transformer

# %%
import tensorflow as tf
import keras.layers as L
from keras.models import Model


def mlp(x, cf):
    x = L.Dense(cf["mlp_dim"], activation="gelu")(x)
    x = L.Dropout(cf["dropout_rate"])(x)
    x = L.Dense(cf["hidden_dim"])(x)
    x = L.Dropout(cf["dropout_rate"])(x)
    return x


def transformer_encoder(x, cf):
    skip_1 = x
    x = L.LayerNormalization()(x)
    x = L.MultiHeadAttention(
        num_heads=cf["num_heads"], key_dim=cf["hidden_dim"]
    )(x, x)
    x = L.Add()([x, skip_1])

    skip_2 = x
    x = L.LayerNormalization()(x)
    x = mlp(x, cf)
    x = L.Add()([x, skip_2])

    return x


def conv_block(x, num_filters, kernel_size=3):
    x = L.Conv2D(num_filters, kernel_size=kernel_size, padding="same")(x)
    x = L.BatchNormalization()(x)
    x = L.ReLU()(x)
    return x


def deconv_block(x, num_filters):
    x = L.Conv2DTranspose(num_filters, kernel_size=2,
                          padding="same", strides=2)(x)
    return x


def build_unetr(cf):
    """ Inputs """
    input_shape = (cf["num_patches"], cf["patch_size"]
                   * cf["patch_size"]*cf["num_channels"])
    inputs = L.Input(input_shape)  # (None, 256, 768)

    """ Patch + Position Embeddings """
    patch_embed = L.Dense(cf["hidden_dim"])(inputs)  # (None, 256, 768)

    positions = tf.range(start=0, limit=cf["num_patches"], delta=1)  # (256,)
    pos_embed = L.Embedding(input_dim=cf["num_patches"], output_dim=cf["hidden_dim"])(
        positions)  # (256, 768)
    x = patch_embed + pos_embed  # (None, 256, 768)

    """ Transformer Encoder """
    skip_connection_index = [3, 6, 9, 12]
    skip_connections = []

    for i in range(1, cf["num_layers"] + 1, 1):
        x = transformer_encoder(x, cf)

        if i in skip_connection_index:
            skip_connections.append(x)

    """ CNN Decoder """
    z3, z6, z9, z12 = skip_connections

    # Reshaping
    z0 = L.Reshape((cf["image_size"], cf["image_size"],cf["num_channels"]))(inputs)
    z3 = L.Reshape((cf["patch_size"], cf["patch_size"], cf["hidden_dim"]))(z3)
    z6 = L.Reshape((cf["patch_size"], cf["patch_size"], cf["hidden_dim"]))(z6)
    z9 = L.Reshape((cf["patch_size"], cf["patch_size"], cf["hidden_dim"]))(z9)
    z12 = L.Reshape((cf["patch_size"], cf["patch_size"], cf["hidden_dim"]))(z12)

    # Decoder 1
    x = deconv_block(z12, 512)

    s = deconv_block(z9, 512)
    s = conv_block(s, 512)
    x = L.Concatenate()([x, s])

    x = conv_block(x, 512)
    x = conv_block(x, 512)

    # Decoder 2
    x = deconv_block(x, 256)

    s = deconv_block(z6, 256)
    s = conv_block(s, 256)
    s = deconv_block(s, 256)
    s = conv_block(s, 256)

    x = L.Concatenate()([x, s])
    x = conv_block(x, 256)
    x = conv_block(x, 256)

    # Decoder 3
    x = deconv_block(x, 128)

    s = deconv_block(z3, 128)
    s = conv_block(s, 128)
    s = deconv_block(s, 128)
    s = conv_block(s, 128)
    s = deconv_block(s, 128)
    s = conv_block(s, 128)

    x = L.Concatenate()([x, s])
    x = conv_block(x, 128)
    x = conv_block(x, 128)

    # Decoder 4
    x = deconv_block(x, 64)

    s = conv_block(z0, 64)
    s = conv_block(s, 64)

    x = L.Concatenate()([x, s])
    x = conv_block(x, 64)
    x = conv_block(x, 64)

    """ Output """
    outputs = L.Conv2D(1, kernel_size=1, padding="same",
                       activation="sigmoid")(x)

    return Model(inputs, outputs, name="UNETR")


model = build_unetr(cf)
model.summary()
# Out:
# Model: "UNETR"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 768)]           0         []
#
#  dense (Dense)               (None, 256, 128)             98432     ['input_1[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 256, 128)             0         ['dense[0][0]']
#  Lambda)
#
#  layer_normalization (Layer  (None, 256, 128)             256       ['tf.__operators__.add[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 256, 128)             395648    ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 256, 128)             0         ['multi_head_attention[0][0]',
#                                                                      'tf.__operators__.add[0][0]']
#
#  layer_normalization_1 (Lay  (None, 256, 128)             256       ['add[0][0]']
#  erNormalization)
#
#  dense_1 (Dense)             (None, 256, 32)              4128      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 256, 32)              0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 256, 128)             4224      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 256, 128)             0         ['dense_2[0][0]']
#
#  add_1 (Add)                 (None, 256, 128)             0         ['dropout_1[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 256, 128)             256       ['add_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 256, 128)             395648    ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 256, 128)             0         ['multi_head_attention_1[0][0]
#                                                                     ',
#                                                                      'add_1[0][0]']
#
#  layer_normalization_3 (Lay  (None, 256, 128)             256       ['add_2[0][0]']
#  erNormalization)
#
#  dense_3 (Dense)             (None, 256, 32)              4128      ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 256, 32)              0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 256, 128)             4224      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 256, 128)             0         ['dense_4[0][0]']
#
#  add_3 (Add)                 (None, 256, 128)             0         ['dropout_3[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_4 (Lay  (None, 256, 128)             256       ['add_3[0][0]']
#  erNormalization)
#
#  multi_head_attention_2 (Mu  (None, 256, 128)             395648    ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 256, 128)             0         ['multi_head_attention_2[0][0]
#                                                                     ',
#                                                                      'add_3[0][0]']
#
#  layer_normalization_5 (Lay  (None, 256, 128)             256       ['add_4[0][0]']
#  erNormalization)
#
#  dense_5 (Dense)             (None, 256, 32)              4128      ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 256, 32)              0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 256, 128)             4224      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 256, 128)             0         ['dense_6[0][0]']
#
#  add_5 (Add)                 (None, 256, 128)             0         ['dropout_5[0][0]',
#                                                                      'add_4[0][0]']
#
#  layer_normalization_6 (Lay  (None, 256, 128)             256       ['add_5[0][0]']
#  erNormalization)
#
#  multi_head_attention_3 (Mu  (None, 256, 128)             395648    ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 256, 128)             0         ['multi_head_attention_3[0][0]
#                                                                     ',
#                                                                      'add_5[0][0]']
#
#  layer_normalization_7 (Lay  (None, 256, 128)             256       ['add_6[0][0]']
#  erNormalization)
#
#  dense_7 (Dense)             (None, 256, 32)              4128      ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 256, 32)              0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 256, 128)             4224      ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 256, 128)             0         ['dense_8[0][0]']
#
#  add_7 (Add)                 (None, 256, 128)             0         ['dropout_7[0][0]',
#                                                                      'add_6[0][0]']
#
#  layer_normalization_8 (Lay  (None, 256, 128)             256       ['add_7[0][0]']
#  erNormalization)
#
#  multi_head_attention_4 (Mu  (None, 256, 128)             395648    ['layer_normalization_8[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_8[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 256, 128)             0         ['multi_head_attention_4[0][0]
#                                                                     ',
#                                                                      'add_7[0][0]']
#  yerNormalization)
#
#  multi_head_attention_5 (Mu  (None, 256, 128)             395648    ['layer_normalization_10[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_10[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 256, 128)             0         ['multi_head_attention_5[0][0]
#                                                                     ',
#                                                                      'add_9[0][0]']
#
#  layer_normalization_11 (La  (None, 256, 128)             256       ['add_10[0][0]']
#  yerNormalization)
#
#  dense_11 (Dense)            (None, 256, 32)              4128      ['layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 256, 32)              0         ['dense_11[0][0]']
#
#  dense_12 (Dense)            (None, 256, 128)             4224      ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 256, 128)             0         ['dense_12[0][0]']
#
#  add_11 (Add)                (None, 256, 128)             0         ['dropout_11[0][0]',
#                                                                      'add_10[0][0]']
#
#  layer_normalization_12 (La  (None, 256, 128)             256       ['add_11[0][0]']
#  yerNormalization)
#
#  multi_head_attention_6 (Mu  (None, 256, 128)             395648    ['layer_normalization_12[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_12[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 256, 128)             0         ['multi_head_attention_6[0][0]
#                                                                     ',
#                                                                      'add_11[0][0]']
#
#  layer_normalization_13 (La  (None, 256, 128)             256       ['add_12[0][0]']
#  yerNormalization)
#
#  dense_13 (Dense)            (None, 256, 32)              4128      ['layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 256, 32)              0         ['dense_13[0][0]']
#
#  dense_14 (Dense)            (None, 256, 128)             4224      ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)        (None, 256, 128)             0         ['dense_14[0][0]']
#
#  add_13 (Add)                (None, 256, 128)             0         ['dropout_13[0][0]',
#                                                                      'add_12[0][0]']
#
#  layer_normalization_14 (La  (None, 256, 128)             256       ['add_13[0][0]']
#  yerNormalization)
#
#  multi_head_attention_7 (Mu  (None, 256, 128)             395648    ['layer_normalization_14[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_14[0][0]
#                                                                     ']
#
#  add_14 (Add)                (None, 256, 128)             0         ['multi_head_attention_7[0][0]
#                                                                     ',
#                                                                      'add_13[0][0]']
#
#  layer_normalization_15 (La  (None, 256, 128)             256       ['add_14[0][0]']
#  yerNormalization)
#
#  dense_15 (Dense)            (None, 256, 32)              4128      ['layer_normalization_15[0][0]
#                                                                     ']
#
#  dropout_14 (Dropout)        (None, 256, 32)              0         ['dense_15[0][0]']
#
#  dense_16 (Dense)            (None, 256, 128)             4224      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 256, 128)             0         ['dense_16[0][0]']
#
#  add_15 (Add)                (None, 256, 128)             0         ['dropout_15[0][0]',
#                                                                      'add_14[0][0]']
#
#  layer_normalization_16 (La  (None, 256, 128)             256       ['add_15[0][0]']
#  yerNormalization)
#
#  multi_head_attention_8 (Mu  (None, 256, 128)             395648    ['layer_normalization_16[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_16[0][0]
#                                                                     ']
#
#  add_16 (Add)                (None, 256, 128)             0         ['multi_head_attention_8[0][0]
#                                                                     ',
#                                                                      'add_15[0][0]']
#
#  layer_normalization_17 (La  (None, 256, 128)             256       ['add_16[0][0]']
#  yerNormalization)
#
#  dense_17 (Dense)            (None, 256, 32)              4128      ['layer_normalization_17[0][0]
#                                                                     ']
#
#  dropout_16 (Dropout)        (None, 256, 32)              0         ['dense_17[0][0]']
#
#  dense_18 (Dense)            (None, 256, 128)             4224      ['dropout_16[0][0]']
#
#  dropout_17 (Dropout)        (None, 256, 128)             0         ['dense_18[0][0]']
#
#  add_17 (Add)                (None, 256, 128)             0         ['dropout_17[0][0]',
#                                                                      'add_16[0][0]']
#
#  layer_normalization_18 (La  (None, 256, 128)             256       ['add_17[0][0]']
#  yerNormalization)
#
#  multi_head_attention_9 (Mu  (None, 256, 128)             395648    ['layer_normalization_18[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_18[0][0]
#                                                                     ']
#
#  add_18 (Add)                (None, 256, 128)             0         ['multi_head_attention_9[0][0]
#                                                                     ',
#                                                                      'add_17[0][0]']
#
#  layer_normalization_19 (La  (None, 256, 128)             256       ['add_18[0][0]']
#  yerNormalization)
#
#  dense_19 (Dense)            (None, 256, 32)              4128      ['layer_normalization_19[0][0]
#                                                                     ']
#
#  dropout_18 (Dropout)        (None, 256, 32)              0         ['dense_19[0][0]']
#
#  dense_20 (Dense)            (None, 256, 128)             4224      ['dropout_18[0][0]']
#
#  dropout_19 (Dropout)        (None, 256, 128)             0         ['dense_20[0][0]']
#
#  add_19 (Add)                (None, 256, 128)             0         ['dropout_19[0][0]',
#                                                                      'add_18[0][0]']
#
#  layer_normalization_20 (La  (None, 256, 128)             256       ['add_19[0][0]']
#  yerNormalization)
#
#  multi_head_attention_10 (M  (None, 256, 128)             395648    ['layer_normalization_20[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_20[0][0]
#                                                                     ']
#
#  add_20 (Add)                (None, 256, 128)             0         ['multi_head_attention_10[0][0
#                                                                     ]',
#                                                                      'add_19[0][0]']
#
#  layer_normalization_21 (La  (None, 256, 128)             256       ['add_20[0][0]']
#  yerNormalization)
#
#  dense_21 (Dense)            (None, 256, 32)              4128      ['layer_normalization_21[0][0]
#                                                                     ']
#
#  dropout_20 (Dropout)        (None, 256, 32)              0         ['dense_21[0][0]']
#
#  dense_22 (Dense)            (None, 256, 128)             4224      ['dropout_20[0][0]']
#
#  dropout_21 (Dropout)        (None, 256, 128)             0         ['dense_22[0][0]']
#
#  add_21 (Add)                (None, 256, 128)             0         ['dropout_21[0][0]',
#                                                                      'add_20[0][0]']
#
#  layer_normalization_22 (La  (None, 256, 128)             256       ['add_21[0][0]']
#  yerNormalization)
#
#  multi_head_attention_11 (M  (None, 256, 128)             395648    ['layer_normalization_22[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_22[0][0]
#                                                                     ']
#
#  add_22 (Add)                (None, 256, 128)             0         ['multi_head_attention_11[0][0
#                                                                     ]',
#                                                                      'add_21[0][0]']
#
#  layer_normalization_23 (La  (None, 256, 128)             256       ['add_22[0][0]']
#  yerNormalization)
#
#  dense_23 (Dense)            (None, 256, 32)              4128      ['layer_normalization_23[0][0]
#                                                                     ']
#
#  dropout_22 (Dropout)        (None, 256, 32)              0         ['dense_23[0][0]']
#
#  dense_24 (Dense)            (None, 256, 128)             4224      ['dropout_22[0][0]']
#
#  reshape_3 (Reshape)         (None, 16, 16, 128)          0         ['add_17[0][0]']
#
#  dropout_23 (Dropout)        (None, 256, 128)             0         ['dense_24[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 512)          262656    ['reshape_3[0][0]']
#  Transpose)
#
#  add_23 (Add)                (None, 256, 128)             0         ['dropout_23[0][0]',
#                                                                      'add_22[0][0]']
#
#  conv2d (Conv2D)             (None, 32, 32, 512)          2359808   ['conv2d_transpose_1[0][0]']
#
#  reshape_4 (Reshape)         (None, 16, 16, 128)          0         ['add_23[0][0]']
#
#  batch_normalization (Batch  (None, 32, 32, 512)          2048      ['conv2d[0][0]']
#  Normalization)
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 512)          262656    ['reshape_4[0][0]']
#  anspose)
#
#  re_lu (ReLU)                (None, 32, 32, 512)          0         ['batch_normalization[0][0]']
#
#  reshape_2 (Reshape)         (None, 16, 16, 128)          0         ['add_11[0][0]']
#
#  concatenate (Concatenate)   (None, 32, 32, 1024)         0         ['conv2d_transpose[0][0]',
#                                                                      're_lu[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 32, 32, 256)          131328    ['reshape_2[0][0]']
#  Transpose)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 512)          4719104   ['concatenate[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 256)          590080    ['conv2d_transpose_3[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 512)          2048      ['conv2d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 256)          1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 32, 32, 512)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  re_lu_3 (ReLU)              (None, 32, 32, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  reshape_1 (Reshape)         (None, 16, 16, 128)          0         ['add_5[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 512)          2359808   ['re_lu_1[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 64, 64, 256)          262400    ['re_lu_3[0][0]']
#  Transpose)
#
#  conv2d_transpose_6 (Conv2D  (None, 32, 32, 128)          65664     ['reshape_1[0][0]']
#  Transpose)
#
#  batch_normalization_2 (Bat  (None, 32, 32, 512)          2048      ['conv2d_2[0][0]']
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 256)          590080    ['conv2d_transpose_4[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)          147584    ['conv2d_transpose_6[0][0]']
#
#  re_lu_2 (ReLU)              (None, 32, 32, 512)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 64, 64, 256)          1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 32, 32, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 64, 256)          524544    ['re_lu_2[0][0]']
#  Transpose)
#
#  re_lu_4 (ReLU)              (None, 64, 64, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  re_lu_7 (ReLU)              (None, 32, 32, 128)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  concatenate_1 (Concatenate  (None, 64, 64, 512)          0         ['conv2d_transpose_2[0][0]',
#  )                                                                   're_lu_4[0][0]']
#
#  conv2d_transpose_7 (Conv2D  (None, 64, 64, 128)          65664     ['re_lu_7[0][0]']
#  Transpose)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 256)          1179904   ['concatenate_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 128)          147584    ['conv2d_transpose_7[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 64, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 64, 64, 128)          512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 64, 64, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  re_lu_8 (ReLU)              (None, 64, 64, 128)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 256)          590080    ['re_lu_5[0][0]']
#
#  conv2d_transpose_8 (Conv2D  (None, 128, 128, 128)        65664     ['re_lu_8[0][0]']
#  Transpose)
#
#  batch_normalization_6 (Bat  (None, 64, 64, 256)          1024      ['conv2d_6[0][0]']
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 128, 128, 128)        147584    ['conv2d_transpose_8[0][0]']
#
#  re_lu_6 (ReLU)              (None, 64, 64, 256)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  batch_normalization_9 (Bat  (None, 128, 128, 128)        512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  conv2d_transpose_5 (Conv2D  (None, 128, 128, 128)        131200    ['re_lu_6[0][0]']
#  Transpose)
#
#  re_lu_9 (ReLU)              (None, 128, 128, 128)        0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  concatenate_2 (Concatenate  (None, 128, 128, 256)        0         ['conv2d_transpose_5[0][0]',
#  )                                                                   're_lu_9[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 128)        295040    ['concatenate_2[0][0]']
#
#  reshape (Reshape)           (None, 256, 256, 3)          0         ['input_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 128, 128, 128)        512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  conv2d_12 (Conv2D)          (None, 256, 256, 64)         1792      ['reshape[0][0]']
#
#  re_lu_10 (ReLU)             (None, 128, 128, 128)        0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  batch_normalization_12 (Ba  (None, 256, 256, 64)         256       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 128)        147584    ['re_lu_10[0][0]']
#
#  re_lu_12 (ReLU)             (None, 256, 256, 64)         0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  batch_normalization_11 (Ba  (None, 128, 128, 128)        512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 256, 256, 64)         36928     ['re_lu_12[0][0]']
#
#  re_lu_11 (ReLU)             (None, 128, 128, 128)        0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  batch_normalization_13 (Ba  (None, 256, 256, 64)         256       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  conv2d_transpose_9 (Conv2D  (None, 256, 256, 64)         32832     ['re_lu_11[0][0]']
#  Transpose)
#
#  re_lu_13 (ReLU)             (None, 256, 256, 64)         0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  concatenate_3 (Concatenate  (None, 256, 256, 128)        0         ['conv2d_transpose_9[0][0]',
#  )                                                                   're_lu_13[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 64)         73792     ['concatenate_3[0][0]']
#
#  batch_normalization_14 (Ba  (None, 256, 256, 64)         256       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 256, 256, 64)         0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 64)         36928     ['re_lu_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 256, 256, 64)         256       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 256, 256, 64)         0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 256, 256, 1)          65        ['re_lu_15[0][0]']
#
# ==================================================================================================
# Total params: 20194753 (77.04 MB)
# Trainable params: 20187841 (77.01 MB)
# Non-trainable params: 6912 (27.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training the UNETR model

# %%
import tensorflow as tf
import numpy as np
import os
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping


smooth = 1e-15


def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)


def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)


""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory for storing files """
create_dir("/kaggle/working/files")

""" Hyperparameters """
batch_size = cf["batch_size"]
optimizer = cf["optimizer"]
num_epochs = 30
model_path = os.path.join("/kaggle/working/files", "model.h5")
csv_path = os.path.join("/kaggle/working/files", "log.csv")

""" Dataset """
dataset_path = "/kaggle/input/brain-tumor-segmentation"
(train_x, train_y), (valid_x, valid_y), (test_x,
                                         test_y) = load_dataset(dataset_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")
print(f"Test : {len(test_x)} - {len(test_y)}")

train_x, train_y = augment_data(train_x, train_y, num_aug_per_image=2, aug_save_path="/kaggle/working/aug_brain-tumor-segmentation")

print(f"Train after augmented: {len(train_x)} - {len(train_y)}")

train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)
# Out:
# Train: 1840 - 1840
# Valid: 612 - 612
# Test : 612 - 612
# Train after augmented: 5520 - 5520

# %%
""" Model """
model = build_unetr(cf)
model.compile(loss=dice_loss, optimizer=optimizer, metrics=[dice_coef])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                      patience=5, min_lr=1e-7, verbose=1),
    CSVLogger(csv_path),
    EarlyStopping(monitor='val_loss', patience=20,
                  restore_best_weights=False),
]

model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711429808.288169     106 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 345/345 [==============================] - ETA: 0s - loss: 0.8803 - dice_coef: 0.1197
# Epoch 1: val_loss improved from inf to 0.93355, saving model to /kaggle/working/files/model.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 345/345 [==============================] - 429s 982ms/step - loss: 0.8803 - dice_coef: 0.1197 - val_loss: 0.9335 - val_dice_coef: 0.0658 - lr: 1.0000e-04
# Epoch 2/30
# 345/345 [==============================] - ETA: 0s - loss: 0.7902 - dice_coef: 0.2098
# Epoch 2: val_loss improved from 0.93355 to 0.75367, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 329s 953ms/step - loss: 0.7902 - dice_coef: 0.2098 - val_loss: 0.7537 - val_dice_coef: 0.2434 - lr: 1.0000e-04
# Epoch 3/30
# 345/345 [==============================] - ETA: 0s - loss: 0.6690 - dice_coef: 0.3310
# Epoch 3: val_loss improved from 0.75367 to 0.70675, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 329s 953ms/step - loss: 0.6690 - dice_coef: 0.3310 - val_loss: 0.7067 - val_dice_coef: 0.2898 - lr: 1.0000e-04
# Epoch 4/30
# 345/345 [==============================] - ETA: 0s - loss: 0.5816 - dice_coef: 0.4184
# Epoch 4: val_loss improved from 0.70675 to 0.60211, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 329s 953ms/step - loss: 0.5816 - dice_coef: 0.4184 - val_loss: 0.6021 - val_dice_coef: 0.3927 - lr: 1.0000e-04
# Epoch 5/30
# 345/345 [==============================] - ETA: 0s - loss: 0.5305 - dice_coef: 0.4695
# Epoch 5: val_loss improved from 0.60211 to 0.55414, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 329s 954ms/step - loss: 0.5305 - dice_coef: 0.4695 - val_loss: 0.5541 - val_dice_coef: 0.4408 - lr: 1.0000e-04
# Epoch 6/30
# 345/345 [==============================] - ETA: 0s - loss: 0.4924 - dice_coef: 0.5076
# Epoch 6: val_loss improved from 0.55414 to 0.53135, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 329s 954ms/step - loss: 0.4924 - dice_coef: 0.5076 - val_loss: 0.5314 - val_dice_coef: 0.4646 - lr: 1.0000e-04
# Epoch 7/30
# 345/345 [==============================] - ETA: 0s - loss: 0.4578 - dice_coef: 0.5422
# Epoch 7: val_loss did not improve from 0.53135
# 345/345 [==============================] - 328s 951ms/step - loss: 0.4578 - dice_coef: 0.5422 - val_loss: 0.5395 - val_dice_coef: 0.4548 - lr: 1.0000e-04
# Epoch 8/30
# 345/345 [==============================] - ETA: 0s - loss: 0.4334 - dice_coef: 0.5666
# Epoch 8: val_loss improved from 0.53135 to 0.47199, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 330s 955ms/step - loss: 0.4334 - dice_coef: 0.5666 - val_loss: 0.4720 - val_dice_coef: 0.5232 - lr: 1.0000e-04
# Epoch 9/30
# 345/345 [==============================] - ETA: 0s - loss: 0.4134 - dice_coef: 0.5866
# Epoch 9: val_loss improved from 0.47199 to 0.45198, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 330s 955ms/step - loss: 0.4134 - dice_coef: 0.5866 - val_loss: 0.4520 - val_dice_coef: 0.5424 - lr: 1.0000e-04
# Epoch 10/30
# 345/345 [==============================] - ETA: 0s - loss: 0.3928 - dice_coef: 0.6072
# Epoch 10: val_loss did not improve from 0.45198
# 345/345 [==============================] - 328s 952ms/step - loss: 0.3928 - dice_coef: 0.6072 - val_loss: 0.4800 - val_dice_coef: 0.5155 - lr: 1.0000e-04
# Epoch 11/30
# 345/345 [==============================] - ETA: 0s - loss: 0.3796 - dice_coef: 0.6204
# Epoch 11: val_loss improved from 0.45198 to 0.44983, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 329s 954ms/step - loss: 0.3796 - dice_coef: 0.6204 - val_loss: 0.4498 - val_dice_coef: 0.5454 - lr: 1.0000e-04
# Epoch 12/30
# 345/345 [==============================] - ETA: 0s - loss: 0.3729 - dice_coef: 0.6271
# Epoch 12: val_loss did not improve from 0.44983
# 345/345 [==============================] - 329s 953ms/step - loss: 0.3729 - dice_coef: 0.6271 - val_loss: 0.4732 - val_dice_coef: 0.5226 - lr: 1.0000e-04
# Epoch 13/30
# 345/345 [==============================] - ETA: 0s - loss: 0.3556 - dice_coef: 0.6444
# Epoch 13: val_loss improved from 0.44983 to 0.41232, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 329s 954ms/step - loss: 0.3556 - dice_coef: 0.6444 - val_loss: 0.4123 - val_dice_coef: 0.5824 - lr: 1.0000e-04
# Epoch 14/30
# 345/345 [==============================] - ETA: 0s - loss: 0.3400 - dice_coef: 0.6600
# Epoch 14: val_loss did not improve from 0.41232
# 345/345 [==============================] - 324s 940ms/step - loss: 0.3400 - dice_coef: 0.6600 - val_loss: 0.4269 - val_dice_coef: 0.5679 - lr: 1.0000e-04
# Epoch 15/30
# 345/345 [==============================] - ETA: 0s - loss: 0.3278 - dice_coef: 0.6722
# Epoch 15: val_loss did not improve from 0.41232
# 345/345 [==============================] - 328s 951ms/step - loss: 0.3278 - dice_coef: 0.6722 - val_loss: 0.4647 - val_dice_coef: 0.5300 - lr: 1.0000e-04
# Epoch 16/30
# 345/345 [==============================] - ETA: 0s - loss: 0.3177 - dice_coef: 0.6823
# Epoch 16: val_loss improved from 0.41232 to 0.39938, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 330s 955ms/step - loss: 0.3177 - dice_coef: 0.6823 - val_loss: 0.3994 - val_dice_coef: 0.5964 - lr: 1.0000e-04
# Epoch 17/30
# 345/345 [==============================] - ETA: 0s - loss: 0.3061 - dice_coef: 0.6939
# Epoch 17: val_loss did not improve from 0.39938
# 345/345 [==============================] - 329s 953ms/step - loss: 0.3061 - dice_coef: 0.6939 - val_loss: 0.4864 - val_dice_coef: 0.5058 - lr: 1.0000e-04
# Epoch 18/30
# 345/345 [==============================] - ETA: 0s - loss: 0.2945 - dice_coef: 0.7055
# Epoch 18: val_loss improved from 0.39938 to 0.38512, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 330s 956ms/step - loss: 0.2945 - dice_coef: 0.7055 - val_loss: 0.3851 - val_dice_coef: 0.6087 - lr: 1.0000e-04
# Epoch 19/30
# 345/345 [==============================] - ETA: 0s - loss: 0.2890 - dice_coef: 0.7110
# Epoch 19: val_loss did not improve from 0.38512
# 345/345 [==============================] - 328s 951ms/step - loss: 0.2890 - dice_coef: 0.7110 - val_loss: 0.4464 - val_dice_coef: 0.5498 - lr: 1.0000e-04
# Epoch 20/30
# 345/345 [==============================] - ETA: 0s - loss: 0.2750 - dice_coef: 0.7250
# Epoch 20: val_loss did not improve from 0.38512
# 345/345 [==============================] - 328s 949ms/step - loss: 0.2750 - dice_coef: 0.7250 - val_loss: 0.4699 - val_dice_coef: 0.5240 - lr: 1.0000e-04
# Epoch 21/30
# 345/345 [==============================] - ETA: 0s - loss: 0.2644 - dice_coef: 0.7356
# Epoch 21: val_loss did not improve from 0.38512
# 345/345 [==============================] - 328s 951ms/step - loss: 0.2644 - dice_coef: 0.7356 - val_loss: 0.4079 - val_dice_coef: 0.5864 - lr: 1.0000e-04
# Epoch 22/30
# 345/345 [==============================] - ETA: 0s - loss: 0.2574 - dice_coef: 0.7426
# Epoch 22: val_loss did not improve from 0.38512
# 345/345 [==============================] - 328s 951ms/step - loss: 0.2574 - dice_coef: 0.7426 - val_loss: 0.4209 - val_dice_coef: 0.5737 - lr: 1.0000e-04
# Epoch 23/30
# 345/345 [==============================] - ETA: 0s - loss: 0.2449 - dice_coef: 0.7551
# Epoch 23: val_loss did not improve from 0.38512
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 345/345 [==============================] - 328s 950ms/step - loss: 0.2449 - dice_coef: 0.7551 - val_loss: 0.4065 - val_dice_coef: 0.5903 - lr: 1.0000e-04
# Epoch 24/30
# 345/345 [==============================] - ETA: 0s - loss: 0.2384 - dice_coef: 0.7616
# Epoch 24: val_loss improved from 0.38512 to 0.31612, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 329s 953ms/step - loss: 0.2384 - dice_coef: 0.7616 - val_loss: 0.3161 - val_dice_coef: 0.6763 - lr: 1.0000e-05
# Epoch 25/30
# 345/345 [==============================] - ETA: 0s - loss: 0.2206 - dice_coef: 0.7794
# Epoch 25: val_loss improved from 0.31612 to 0.31033, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 329s 954ms/step - loss: 0.2206 - dice_coef: 0.7794 - val_loss: 0.3103 - val_dice_coef: 0.6820 - lr: 1.0000e-05
# Epoch 26/30
# 345/345 [==============================] - ETA: 0s - loss: 0.2132 - dice_coef: 0.7868
# Epoch 26: val_loss did not improve from 0.31033
# 345/345 [==============================] - 329s 953ms/step - loss: 0.2132 - dice_coef: 0.7868 - val_loss: 0.3143 - val_dice_coef: 0.6779 - lr: 1.0000e-05
# Epoch 27/30
# 345/345 [==============================] - ETA: 0s - loss: 0.2091 - dice_coef: 0.7909
# Epoch 27: val_loss did not improve from 0.31033
# 345/345 [==============================] - 329s 952ms/step - loss: 0.2091 - dice_coef: 0.7909 - val_loss: 0.3126 - val_dice_coef: 0.6796 - lr: 1.0000e-05
# Epoch 28/30
# 345/345 [==============================] - ETA: 0s - loss: 0.2044 - dice_coef: 0.7956
# Epoch 28: val_loss did not improve from 0.31033
# 345/345 [==============================] - 329s 953ms/step - loss: 0.2044 - dice_coef: 0.7956 - val_loss: 0.3110 - val_dice_coef: 0.6811 - lr: 1.0000e-05
# Epoch 29/30
# 345/345 [==============================] - ETA: 0s - loss: 0.1993 - dice_coef: 0.8007
# Epoch 29: val_loss improved from 0.31033 to 0.30608, saving model to /kaggle/working/files/model.h5
# 345/345 [==============================] - 330s 955ms/step - loss: 0.1993 - dice_coef: 0.8007 - val_loss: 0.3061 - val_dice_coef: 0.6859 - lr: 1.0000e-05
# Epoch 30/30
# 345/345 [==============================] - ETA: 0s - loss: 0.1964 - dice_coef: 0.8036
# Epoch 30: val_loss did not improve from 0.30608
# 345/345 [==============================] - 328s 951ms/step - loss: 0.1964 - dice_coef: 0.8036 - val_loss: 0.3097 - val_dice_coef: 0.6824 - lr: 1.0000e-05

# %% [markdown]
# ## Testing & Evaluation

# %%
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score
import tensorflow as tf
from tqdm import tqdm
import pandas as pd
import cv2
import numpy as np
import os
from patchify import patchify

# %%
def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((cf["image_size"], 10, 3)) * 255
    
    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory for storing files """
create_dir("/kaggle/working/results")

""" Load the model """
model_path = os.path.join("/kaggle/working/files", "model.h5")
model = tf.keras.models.load_model(model_path, custom_objects={"dice_loss": dice_loss, "dice_coef": dice_coef})

""" Dataset """
dataset_path = "/kaggle/input/brain-tumor-segmentation"
(train_x, train_y), (valid_x, valid_y), (test_x,
                                            test_y) = load_dataset(dataset_path)

""" Prediction and Evaluation """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_y)):
    """ Extracting the name """
    name = x.replace("\\", "/").split("/")[-1]

    """ Reading the image """
    image = cv2.imread(x, cv2.IMREAD_COLOR)  # [512, 512, 3]
    image = cv2.resize(
        image, (cf["image_size"], cf["image_size"]))  # [256, 256, 3]
    x = image / 255.0  # [256, 256, 3]

    patch_shape = (cf["patch_size"], cf["patch_size"], cf["num_channels"]) # (16, 16, 3)
    patches = patchify(x, patch_shape, cf["patch_size"])
    patches = np.reshape(patches, cf["flat_patches_shape"]) # [256, 768]
    patches = patches.astype(np.float32) # [256, 768]
    patches = np.expand_dims(patches, axis=0) # [1, 256, 768]

    """ Reading the mask """
    mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE) # [512, 512]
    mask = cv2.resize(mask, (cf["image_size"], cf["image_size"])) # [256, 256]

    """ Prediction """
    y_pred = model.predict(patches, verbose=0)[0] # [256, 256, 1]
    y_pred = np.squeeze(y_pred, axis=-1) # [256, 256]
    y_pred = y_pred >= 0.5 # [256, 256]
    y_pred = y_pred.astype(np.int32) # [256, 256]

    """ Saving the prediction """
    save_image_path = os.path.join("/kaggle/working/results", name)
    save_results(image, mask, y_pred, save_image_path)

    """ Flatten the array """
    mask = mask / 255.0
    mask = (mask > 0.5).astype(np.int32).flatten()
    y_pred = y_pred.flatten()

    """ Calculating the metrics values """
    f1_value = f1_score(mask, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(mask, y_pred, labels=[
                                0, 1], average="binary")
    recall_value = recall_score(
        mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
    precision_value = precision_score(
        mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
    SCORE.append([name, f1_value, jac_value,
                    recall_value, precision_value])
    
""" Metrics values """
score = [s[1:]for s in SCORE]
score = np.mean(score, axis=0)
print(f"F1: {score[0]:0.5f}")
print(f"Jaccard: {score[1]:0.5f}")
print(f"Recall: {score[2]:0.5f}")
print(f"Precision: {score[3]:0.5f}")

df = pd.DataFrame(
    SCORE, columns=["Image", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("/kaggle/working/files/score.csv")
# Out:
# 100%|██████████| 612/612 [02:57<00:00,  3.46it/s]
# F1: 0.60161
# Jaccard: 0.50582
# Recall: 0.60382
# Precision: 0.68353

# %%
import matplotlib.pyplot as plt

# Function to display an image with its mask and predicted mask
def display_image_with_masks(image, mask, predicted_mask):
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    
    # Display the original image
    axes[0].imshow(image)
    axes[0].set_title('Original Image')
    
    # Display the ground truth mask
    axes[1].imshow(mask, cmap='gray')
    axes[1].set_title('Ground Truth Mask')
    
    # Display the predicted mask
    axes[2].imshow(predicted_mask, cmap='gray')
    axes[2].set_title('Predicted Mask')
    
    plt.show()

# Iterate over test images and display each image with its masks
for x, y in zip(test_x, test_y):
    # Read the image
    image = cv2.imread(x, cv2.IMREAD_COLOR)
    image = cv2.resize(image, (cf["image_size"], cf["image_size"]))
    
    # Read the ground truth mask
    mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (cf["image_size"], cf["image_size"]))
    
    # Predict the mask
    patches = patchify(image / 255.0, patch_shape, cf["patch_size"])
    patches = np.reshape(patches, cf["flat_patches_shape"])
    patches = patches.astype(np.float32)
    patches = np.expand_dims(patches, axis=0)
    y_pred = model.predict(patches, verbose=0)[0]
    y_pred = np.squeeze(y_pred, axis=-1) >= 0.5
    
    # Display the image with its masks
    display_image_with_masks(image, mask, y_pred)
